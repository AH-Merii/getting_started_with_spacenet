# %% [markdown]
# ## Import Libraries

# %%
import gdal
import geopandas as gpd
import pandas as pd 
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
import matplotlib as mpl
import rasterio
from rasterio.plot import show

# %% [markdown]
# ## Plotting Settings

# %%
# %matplotlib inline

# %%
dpi = 200
mpl.rcParams['figure.dpi']= dpi

# %% [markdown]
# ## Read Data

# %%
gdf = pd.read_pickle('gdf')

# %%
gdf.head()
# Out:
#                                                3band  \
# 0  /home/ahm/Datascience/Satellite Imagery Detect...
# 1  /home/ahm/Datascience/Satellite Imagery Detect...
# 2  /home/ahm/Datascience/Satellite Imagery Detect...
# 3  /home/ahm/Datascience/Satellite Imagery Detect...
# 4  /home/ahm/Datascience/Satellite Imagery Detect...
#
#                                                8band  \
# 0  /home/ahm/Datascience/Satellite Imagery Detect...
# 1  /home/ahm/Datascience/Satellite Imagery Detect...
# 2  /home/ahm/Datascience/Satellite Imagery Detect...
# 3  /home/ahm/Datascience/Satellite Imagery Detect...
# 4  /home/ahm/Datascience/Satellite Imagery Detect...
#
#                                              geojson  image_number  geoshape
# 0  /home/ahm/Datascience/Satellite Imagery Detect...            12   (5, 19)
# 1  /home/ahm/Datascience/Satellite Imagery Detect...            30   (2, 19)
# 2  /home/ahm/Datascience/Satellite Imagery Detect...            44   (1, 19)
# 3  /home/ahm/Datascience/Satellite Imagery Detect...            46  (11, 19)
# 4  /home/ahm/Datascience/Satellite Imagery Detect...            47  (15, 19)

# %%
path = str(gdf['8band'][0])
raster = gdal.Open(path)

# %% [markdown]
# ## Print Basic Raster Info

# %%
print(raster.RasterXSize,raster.RasterYSize)

# %%
raster.GetProjection().split('],')
# Out:
# ['GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]',
#  'AUTHORITY["EPSG","6326"]',
#  'PRIMEM["Greenwich",0',
#  'UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]',
#  'AXIS["Latitude",NORTH',
#  'AXIS["Longitude",EAST',
#  'AUTHORITY["EPSG","4326"]]']

# %%
top_left_x,x_resolution,_,top_left_y,__,y_resolution = raster.GetGeoTransform()

# %%
print('top left x coordinate: ', top_left_x)
print()
print('x resolution or cell width in the x direction: ', x_resolution)
print()
print('top left y coordinate: ', top_left_y)
print()
print('y resolution or cell width in the y direction: ', y_resolution)
# Out:
# top left x coordinate:  -43.7732462563
#
# x resolution or cell width in the x direction:  1.7875319090876474e-05
#
# top left y coordinate:  -22.9214851954
#
# y resolution or cell width in the y direction:  -1.803334455447167e-05

# %%
print('Number of Raster Bands: ', raster.RasterCount)
# Out:
# Number of Raster Bands:  8

# %% [markdown]
# ## Print Raster Band Info

# %%
band1 = raster.GetRasterBand(1)

# %%
print('Band 1 No Data Value: ',band1.GetNoDataValue())
# Out:
# Band 1 No Data Value:  None

# %%
print('Band 1 Minimum Value:',band1.GetMinimum())
# Out:
# Band 1 Minimum Value: None

# %%
print('Band 1 Maximum Value:',band1.GetMaximum())
# Out:
# Band 1 Maximum Value: None

# %%
print('Band 1 Data Type:',band1.GetUnitType())
# Out:
# Band 1 Data Type:

# %% [markdown]
# ## Read Band as Numpy Array

# %%
band1 = band1.ReadAsArray()

# %%
band1.shape
# Out:
# (101, 110)

# %%
plt.imshow(band1);

# %% [markdown]
# ## Compare Raster Image with Corresponding GeoJSON Vector

# %%
g_path = gdf['geojson'][0]

# %%
g = gpd.read_file(g_path)

# %%
g
# Out:
#                    timestamp version changeset    user uid   HGIS_OID  \
# 0  2016-06-22T21:31:07+00:00       1      5404  Derick  43  1177981.0
# 1  2016-06-22T21:40:10+00:00       1      5404  Derick  43    15688.0
# 2  2016-06-22T22:01:06+00:00       1      5405  Derick  43  1177983.0
# 3  2016-06-22T22:13:46+00:00       1      5405  Derick  43  1177993.0
# 4  2016-06-22T22:28:09+00:00       1      5405  Derick  43    15689.0
#
#   building  type          id  area                QAStatus    HGISOID  \
# 0      yes  None   way/78096  None  Modified_Original_Rev1  1177981.0
# 1      yes  None   way/86252  None  Modified_Original_Rev1    15688.0
# 2      yes  None  way/103746  None  Modified_Original_Rev1  1177983.0
# 3      yes  None  way/113992  None  Modified_Original_Rev1  1177993.0
# 4      yes  None  way/124541  None  Modified_Original_Rev1    15689.0
#
#   TaskArea Revision1  Shape_Leng  Shape_Area  partialBuilding  partialDec  \
# 0     West       Yes    0.000194         0.0              0.0         1.0
# 1     West       Yes    0.000383         0.0              0.0         1.0
# 2     West       Yes    0.000212         0.0              0.0         1.0
# 3     West       Yes    0.000286         0.0              0.0         1.0
# 4     West       Yes    0.000454         0.0              0.0         1.0
#
#                                             geometry
# 0  POLYGON Z ((-43.77204 -22.92223 0.00000, -43.7...
# 1  POLYGON Z ((-43.77190 -22.92195 0.00000, -43.7...
# 2  POLYGON Z ((-43.77210 -22.92220 0.00000, -43.7...
# 3  POLYGON Z ((-43.77186 -22.92189 0.00000, -43.7...
# 4  POLYGON Z ((-43.77164 -22.92184 0.00000, -43.7...

# %% [markdown]
# ### You can plot the polygons and color them depending on attribute of the geodataframe

# %%
g.plot(column='Shape_Leng');

# %% [markdown]
# ## Opening and plotting raster with rasterio

# %%
r = rasterio.open(path)

# %%
show(r);

# %% [markdown]
# ## Get the Number of Bands in the Raster File

# %%
r.count
# Out:
# 8

# %%
r.width
# Out:
# 110

# %%
r.height
# Out:
# 101

# %%
r.bounds
# Out:
# BoundingBox(left=-43.7732462563, bottom=-22.9233065632, right=-43.7712799712, top=-22.9214851954)

# %%
r.crs
# Out:
# CRS.from_epsg(4326)

# %%
# Out:
# ('uint16',
#  'uint16',
#  'uint16',
#  'uint16',
#  'uint16',
#  'uint16',
#  'uint16',
#  'uint16')

# %% [markdown]
# ### Equivelant to GDAL GeoTransform

# %%
r.transform
# Out:
# Affine(1.7875319090876474e-05, 0.0, -43.7732462563,
#        0.0, -1.803334455447167e-05, -22.9214851954)

# %% [markdown]
# ## Attributes of a rasterio DatasetReader
#
#
#     driver: the name of the desired format driver
#
#     width: the number of columns of the dataset
#
#     height: the number of rows of the dataset
#
#     count: a count of the dataset bands
#
#     dtype: the data type of the dataset
#
#     crs: a coordinate reference system identifier or description
#
#     transform: an affine transformation matrix, and
#
#     nodata: a “nodata” value

# %% [markdown]
# ## Overlaying Polygon ontop of raster file

# %% [markdown]
# ### You can get the current axis in matplotlib using mpl.pyplot.gca
